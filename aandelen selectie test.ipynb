# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from pws_library import cointegration_test, get_data
import matplotlib.pyplot as plt
import seaborn as sn

# %%
tickers = ['SPY',
    'EOG',
    'VLO',
    'MPC',
    'OXY',
    'XOM',
    'CVX',
    'PSX',
    'COP']

df = get_data(tickers, start="2010-01-01", end="2015-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df = df.dropna(axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1258 entries, 2010-01-04 00:00:00 to 2014-12-31 00:00:00
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPY     1258 non-null   float64
#  1   EOG     1258 non-null   float64
#  2   VLO     1258 non-null   float64
#  3   OXY     1258 non-null   float64
#  4   XOM     1258 non-null   float64
#  5   CVX     1258 non-null   float64
#  6   COP     1258 non-null   float64
# dtypes: float64(7)
# memory usage: 78.6+ KB

# %%
corr = df.corr()
corr

plt.figure(figsize=(6,4), dpi=200)
sn.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
cointegration_test('XOM', 'CVX', start="2010-01-01", end="2015-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# beta:0.6698324275958232
# alpha:8.24629167068946
# 0.06036697529783176
# 55.61815089818934
# beta:1.4107674642505754
# alpha:-7.829297691918896
# 0.047633545670704255
# 54.11080481855838
# {'dep': 'CVX',
#  'indep': 'XOM',
#  'beta': 1.4107674642505754,
#  'alpha': -7.829297691918896,
#  'p-value': 0.047633545670704255,
#  'halflife': 54.11080481855838}
